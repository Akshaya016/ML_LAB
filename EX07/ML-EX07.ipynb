# %%
# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.10.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: defusedxml in C:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in C:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.6.0)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.9.10-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in C:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.70.1)
# Requirement already satisfied: colorama in C:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: cloudpickle>=3.0 in C:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from joblib->nltk) (3.1.2)
# Downloading nltk-3.10.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.1 MB/s  0:00:00
# Downloading regex-2026.9.10-cp313-cp313-win_amd64.whl (277 kB)
# Installing collected packages: regex, nltk
#
#    ---------------------------------------- 0/2 [regex]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    ---------------------------------------- 2/2 [nltk]
#
# Successfully installed nltk-3.10.3 regex-2026.9.10
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\Asus\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd 
import nltk 
import re  
nltk.download('stopwords') 
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
df=pd.read_csv("Restaurant_Reviews.tsv",delimiter='\t', quoting=3)  
df.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
df.shape
# Out:
# (1000, 2)

# %%
corpus = []

for i in range(0, 1000):
    review = re.sub(
        pattern='[^a-zA-Z]',
        repl=' ',
        string=df['Review'][i]
    )

    review = review.lower()
    review_words = review.split()

    review_words = [
        word for word in review_words
        if word not in set(stopwords.words('english'))
    ]

    ps = PorterStemmer()

    review_words = [
        ps.stem(word)
        for word in review_words
    ]

    review = ' '.join(review_words)

    corpus.append(review)

print(corpus[0:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 corpus = []
#       2
#       3 for i in range(0, 1000):
# ----> 4     review = re.sub(
#       5         pattern='[^a-zA-Z]',
#       6         repl=' ',
#       7         string=df['Review'][i]
#
# NameError: name 're' is not defined

# %%
import re
import nltk

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus = []

for i in range(0, 1000):
    review = re.sub(
        pattern='[^a-zA-Z]',
        repl=' ',
        string=df['Review'][i]
    )

    review = review.lower()
    review_words = review.split()

    review_words = [
        word for word in review_words
        if word not in set(stopwords.words('english'))
    ]

    ps = PorterStemmer()

    review_words = [
        ps.stem(word)
        for word in review_words
    ]

    review = ' '.join(review_words)

    corpus.append(review)

print(corpus[0:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       3 for i in range(0, 1000):
#       4     review = re.sub(
#       5         pattern='[^a-zA-Z]',
#       6         repl=' ',
# ----> 7         string=df['Review'][i]
#       8     )
#       9
#      10     review = review.lower()
#
# NameError: name 'df' is not defined

# %%
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(df.columns)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("Restaurant_Reviews.tsv", delimiter="\t")

print(df.head())
print(df.columns)
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# Index(['Review', 'Liked'], dtype='str')

# %%
import re
import nltk

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus = []

for i in range(0, 1000):
    review = re.sub(
        pattern='[^a-zA-Z]',
        repl=' ',
        string=df['Review'][i]
    )

    review = review.lower()
    review_words = review.split()

    review_words = [
        word for word in review_words
        if word not in set(stopwords.words('english'))
    ]

    ps = PorterStemmer()

    review_words = [
        ps.stem(word)
        for word in review_words
    ]

    review = ' '.join(review_words)

    corpus.append(review)

print(corpus[0:10])
# Out:
# ['wow love place', 'crust good', 'tasti textur nasti', 'stop late may bank holiday rick steve recommend love', 'select menu great price', 'get angri want damn pho', 'honeslti tast fresh', 'potato like rubber could tell made ahead time kept warmer', 'fri great', 'great touch']

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=1500)

X = cv.fit_transform(corpus).toarray()

y = df.iloc[:, 1].values 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=0
)
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=35)

model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.69

# %%
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

score1 = accuracy_score(y_test, y_pred)
score2 = precision_score(y_test, y_pred)
score3 = recall_score(y_test, y_pred)

print("---- Scores ----")
print("Accuracy score is: {}%".format(round(score1 * 100, 2)))
print("Precision score is: {}".format(round(score2, 2)))
print("Recall score is: {}".format(round(score3, 2)))
# Out:
# ---- Scores ----
# Accuracy score is: 69.0%
# Precision score is: 0.79
# Recall score is: 0.54

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.figure(figsize=(5, 5))

sns.heatmap(
    cm,
    annot=True,
    cmap="YlGnBu",
    xticklabels=['Negative', 'Positive'],
    yticklabels=['Negative', 'Positive']
)

plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.show()

# %%
best_accuracy = 0.0
n_estimators = 5

for i in np.arange(1, 30, 2):
    temp_classifier = RandomForestClassifier(n_estimators=i)
    temp_classifier.fit(X_train, y_train)

    temp_y_pred = temp_classifier.predict(X_test)

    score = accuracy_score(y_test, temp_y_pred)

    print(
        "Accuracy score for n_estimators={} is: {}%".format(
            round(i, 1),
            round(score * 100, 2)
        )
    )

    if score > best_accuracy:
        best_accuracy = score
        n_estimators_val = i

    print(' ')

print(
    'The best accuracy is {}% with n_estimators value as {}'.format(
        round(best_accuracy * 100, 2),
        round(n_estimators_val, 1)
    )
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 best_accuracy = 0.0
#       2 n_estimators = 5
#       3
# ----> 4 for i in np.arange(1, 30, 2):
#       5     temp_classifier = RandomForestClassifier(n_estimators=i)
#       6     temp_classifier.fit(X_train, y_train)
#       7
#
# NameError: name 'np' is not defined

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
best_accuracy = 0.0
n_estimators = 5

for i in np.arange(1, 30, 2):
    temp_classifier = RandomForestClassifier(n_estimators=i)
    temp_classifier.fit(X_train, y_train)

    temp_y_pred = temp_classifier.predict(X_test)

    score = accuracy_score(y_test, temp_y_pred)

    print(
        "Accuracy score for n_estimators={} is: {}%".format(
            round(i, 1),
            round(score * 100, 2)
        )
    )

    if score > best_accuracy:
        best_accuracy = score
        n_estimators_val = i

    print(' ')

print(
    'The best accuracy is {}% with n_estimators value as {}'.format(
        round(best_accuracy * 100, 2),
        round(n_estimators_val, 1)
    )
)
# Out:
# Accuracy score for n_estimators=1 is: 67.0%
#
# Accuracy score for n_estimators=3 is: 65.5%
#
# Accuracy score for n_estimators=5 is: 63.0%
#
# Accuracy score for n_estimators=7 is: 67.0%
#
# Accuracy score for n_estimators=9 is: 72.5%
#
# Accuracy score for n_estimators=11 is: 74.5%
#
# Accuracy score for n_estimators=13 is: 69.0%
#
# Accuracy score for n_estimators=15 is: 69.0%
#
# Accuracy score for n_estimators=17 is: 69.0%
#
# Accuracy score for n_estimators=19 is: 69.5%
#
# Accuracy score for n_estimators=21 is: 69.0%
#
# Accuracy score for n_estimators=23 is: 74.0%
#
# Accuracy score for n_estimators=25 is: 69.0%
#
# Accuracy score for n_estimators=27 is: 69.5%
#
# Accuracy score for n_estimators=29 is: 73.0%
#
# The best accuracy is 74.5% with n_estimators value as 11

# %%
model = RandomForestClassifier(n_estimators=n_estimators_val)
model.fit(X_train, y_train) 
RandomForestClassifier(n_estimators=19)
# Out:
# RandomForestClassifier(n_estimators=19)

# %%
def predict_sentiment(sample_review):
    sample_review = re.sub(
        pattern='[^a-zA-Z]',
        repl=' ',
        string=sample_review
    )

    sample_review = sample_review.lower()
    sample_review_words = sample_review.split()

    sample_review_words = [
        word for word in sample_review_words
        if word not in set(stopwords.words('english'))
    ]

    ps = PorterStemmer()

    final_review = [
        ps.stem(word)
        for word in sample_review_words
    ]

    final_review = ' '.join(final_review)

    temp = cv.transform([final_review]).toarray()

    return model.predict(temp)


sample_review = 'The food is really good here.'

print("Review:", sample_review)

if predict_sentiment(sample_review):
    print('This is a POSITIVE review.')
else:
    print('This is a NEGATIVE review!')
# Out:
# Review: The food is really good here.
# This is a POSITIVE review.

# %%
sample_review = 'Food was pretty bad and the service was very slow.'

print("Review:", sample_review)

if predict_sentiment(sample_review):
    print('This is a POSITIVE review.')
else:
    print('This is a NEGATIVE review!')
# Out:
# Review: Food was pretty bad and the service was very slow.
# This is a NEGATIVE review!

# %%
sample_review = 'The food was absolutely wonderful and nicely presentation'

print("Review:", sample_review)

if predict_sentiment(sample_review):
    print('This is a POSITIVE review.')
else:
    print('This is a NEGATIVE review!')
# Out:
# Review: The food was absolutely wonderful and nicely presentation
# This is a POSITIVE review.
